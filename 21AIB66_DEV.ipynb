# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveena1108/DEV/blob/main/21AIB66_DEV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_csv("winequalityN.csv")
df=df.head(250)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  250 non-null    object
#  1   fixed acidity         247 non-null    float64
#  2   volatile acidity      249 non-null    float64
#  3   citric acid           250 non-null    float64
#  4   residual sugar        249 non-null    float64
#  5   chlorides             249 non-null    float64
#  6   free sulfur dioxide   250 non-null    float64
#  7   total sulfur dioxide  250 non-null    float64
#  8   density               250 non-null    float64
#  9   pH                    248 non-null    float64
#  10  sulphates             249 non-null    float64
#  11  alcohol               250 non-null    float64
#  12  quality               250 non-null    int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 25.5+ KB

# %%
df.shape
# Out:
# (250, 13)

# %%
df.nunique()
# Out:
# type                      1
# fixed acidity            34
# volatile acidity         53
# citric acid              49
# residual sugar          109
# chlorides                54
# free sulfur dioxide      68
# total sulfur dioxide    131
# density                  78
# pH                       56
# sulphates                45
# alcohol                  40
# quality                   5
# dtype: int64

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           3
# volatile acidity        1
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      2
# sulphates               1
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.bar(df['fixed acidity'],df['volatile acidity'], label="greens Bar" ,color='g')
plt.xlabel("fixed acidity")
plt.ylabel("volatile acidity")
plt.title("winequalityN")
plt.legend()
plt.show()

# %%
df.plot.area()

# %%
plt.hist(df['citric acid'],color='blue')
plt.title('citric histogram')
# Out:
# Text(0.5, 1.0, 'citric histogram')

# %%
sns.displot(df["citric acid"],bins=100)

# %%
sns.heatmap(df.corr())

# %%
df.plot(kind="scatter",x="pH",y="sulphates")

# %%
x=df.alcohol    
plt.pie(x)
plt.show(50)

# %%
plt.polar(x)
plt.show()
